# %% [markdown]
# 필요한 패키지를 가져옵니다.

# %%
import numpy as np
import matplotlib.pyplot as plt

from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense, Conv2D, MaxPooling2D, Flatten
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.utils import plot_model, to_categorical
from tensorflow.keras.datasets import mnist

# %% [markdown]
# 이미지 데이터셋을 불러옵니다.

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()

print('x_train shape : ' + str(x_train.shape))
print('y_train shape : ' + str(y_train.shape))
print('x_test shape : ' + str(x_test.shape))
print('y_test shape : ' + str(y_test.shape))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step
# x_train shape : (60000, 28, 28)
# y_train shape : (60000,)
# x_test shape : (10000, 28, 28)
# y_test shape : (10000,)

# %% [markdown]
# 테스트할 샘플 하나를 살펴봅니다.

# %%
import matplotlib.pyplot as plt

plt.imshow(x_test[0], cmap='gray')

# %% [markdown]
# 인공지능 모델이 이 이미지를 입력받았을 때, 해당하는 숫자를 출력할 수 있도록 만드는 것이 목표입니다. 우리는 y_test 라벨값도 가지고 있어서 바로 확인은 할 수 있으나, 모델 학습 시에는 사용이 되지 않으며, 시험 평가할 때만 사용됩니다.

# %%
print(y_test[0])
# Out:
# 7

# %% [markdown]
# 이미지와 라벨과 함께 같이 가시화 시킵니다.

# %%
fig, axes = plt.subplots(nrows=10, ncols=10, figsize=(13, 15), 
                         subplot_kw={'xticks': [], 'yticks': []})

for i, ax in enumerate(axes.flat):
    ax.imshow(x_train[i], cmap = 'gray')
    title = str(y_train[i])
    ax.set_title(title)

plt.show()

# %% [markdown]
# 모델 학습에 용이하도록 다음과 같이 데이터 전처리를 수행합니다.
#
# *   데이터 전처리
#     * 3차원(샘플수, 세로, 가로)를 4차원(샘플수, 세로, 가로, 채널)으로 변경
#     * 정수를 실수로 변경
#     * 0 ~ 255 사이의 수치를 0.0 ~ 1.0 사이로 정규화 수행
# *   라벨 전처리
#     * 0 ~ 9 라벨에 대한 원핫인코딩 수행

# %%
x_train = x_train.reshape(60000, 28, 28, 1).astype('float32') / 255.0
x_test = x_test.reshape(10000, 28, 28, 1).astype('float32') / 255.0
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# %% [markdown]
# 모델은 다음과 같이 구성하였습니다.
#
# * 입력: 3차원 벡터 (세로 28, 가로 28, 채널 1)
# * 출력: 10개 벡터
# * 출력층의 활성화 함수: 소프트맥스
# * 손실함수: categorical_crossentropy
# * 최적화기: adam
# * 평가 메트릭: accuracy
#
# 컨볼루션 신경망을 구성하기 위해, 컨볼루션 레이어, 맥스풀링 레이어, 플래튼 레이어를 사용하였습니다.

# %%
model = Sequential([
    Conv2D(32, (3, 3), padding='same', input_shape=(28, 28, 1), activation='relu'),
    Conv2D(32, (3, 3), padding='same', activation='relu'), 
    MaxPooling2D(pool_size=(2, 2)), 
    Conv2D(64, (3, 3), padding='same', activation='relu'), 
    Conv2D(64, (3, 3), padding='same', activation='relu'), 
    MaxPooling2D(pool_size=(2, 2)), 
    Flatten(), 
    Dense(512, activation='relu'), 
    Dense(10, activation='softmax')
])

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %% [markdown]
# 모델 네트워크 아키텍처 구성을 그려보겠습니다.

# %%
plot_model(model, show_shapes=True)

# %% [markdown]
# 모델을 학습시킬 때, validation_split 옵션을 두면 훈련셋 일부를 검증셋으로 설정할 수 있습니다. 0.2로 설정할 경우, 전체 훈련셋에서 20%를 검증셋, 나머지를 훈련셋으로 구성하여 학습합니다.
#
# 콜백함수를 사용하여, 매 에포크마다 검증셋의 손실값을 체크한 후, 이전 손실값보다 낮은 경우 모델을 파일로 저장합니다. 즉 학습 종료가 되면, "best_model.h5" 파일에 저장된 모델은 손실값이 가장 낮을 때의 가중치를 가지고 있습니다.

# %%
checkpoint_callback = ModelCheckpoint("best_model.h5", 
                                      save_best_only=True, 
                                      monitor="val_loss")

hist = model.fit(x_train, y_train, 
                 validation_split=0.2, 
                 batch_size=32,
                 epochs=100,  
                 callbacks=[checkpoint_callback])
# Out:
# Epoch 1/100
# 1500/1500 [==============================] - 20s 5ms/step - loss: 0.1191 - accuracy: 0.9630 - val_loss: 0.0505 - val_accuracy: 0.9843
# Epoch 2/100
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.0385 - accuracy: 0.9877 - val_loss: 0.0403 - val_accuracy: 0.9889
# Epoch 3/100
# 1500/1500 [==============================] - 8s 6ms/step - loss: 0.0271 - accuracy: 0.9915 - val_loss: 0.0356 - val_accuracy: 0.9882
# Epoch 4/100
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.0186 - accuracy: 0.9944 - val_loss: 0.0429 - val_accuracy: 0.9899
# Epoch 5/100
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.0155 - accuracy: 0.9952 - val_loss: 0.0401 - val_accuracy: 0.9902
# Epoch 6/100
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.0124 - accuracy: 0.9962 - val_loss: 0.0327 - val_accuracy: 0.9921
# Epoch 7/100
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.0113 - accuracy: 0.9968 - val_loss: 0.0473 - val_accuracy: 0.9883
# Epoch 8/100
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.0099 - accuracy: 0.9969 - val_loss: 0.0356 - val_accuracy: 0.9913
# Epoch 9/100
# 1500/1500 [==============================] - 8s 6ms/step - loss: 0.0069 - accuracy: 0.9979 - val_loss: 0.0382 - val_accuracy: 0.9918
# Epoch 10/100
# 1500/1500 [==============================] - 7s 5ms/step - loss: 0.0075 - accuracy: 0.9976 - val_loss: 0.0502 - val_accuracy: 0.9890
# Epoch 11/100
# 1500/1500 [==============================] - 8s 6ms/step - loss: 0.0072 - accuracy: 0.9978 - val_loss: 0.0522 - val_accuracy: 0.9881
# Epoch 12/100
# 1500/1500 [==============================] - 8s 6ms/step - loss: 0.0070 - accuracy: 0.9977 - val_loss: 0.0434 - val_accuracy: 0.9912
# Epoch 13/100
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.0056 - accuracy: 0.9984 - val_loss: 0.0548 - val_accuracy: 0.9904
# Epoch 14/100
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.0058 - accuracy: 0.9985 - val_loss: 0.0577 - val_accuracy: 0.9904
# Epoch 15/100
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.0059 - accuracy: 0.9985 - val_loss: 0.0648 - val_accuracy: 0.9908
# Epoch 16/100
# 1500/1500 [==============================] - 7s 5ms/step - loss: 0.0048 - accuracy: 0.9985 - val_loss: 0.0703 - val_accuracy: 0.9917
# Epoch 17/100
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.0063 - accuracy: 0.9983 - val_loss: 0.0557 - val_accuracy: 0.9912
# Epoch 18/100
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.0035 - accuracy: 0.9990 - val_loss: 0.0915 - val_accuracy: 0.9887
# Epoch 19/100
# 1500/1500 [==============================] - 7s 5ms/step - loss: 0.0050 - accuracy: 0.9988 - val_loss: 0.0538 - val_accuracy: 0.9922
# Epoch 20/100
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.0050 - accuracy: 0.9984 - val_loss: 0.0849 - val_accuracy: 0.9908
# Epoch 21/100
# 1500/1500 [==============================] - 7s 5ms/step - loss: 0.0054 - accuracy: 0.9986 - val_loss: 0.0747 - val_accuracy: 0.9914
# Epoch 22/100
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.0035 - accuracy: 0.9992 - val_loss: 0.0865 - val_accuracy: 0.9899
# Epoch 23/100
# 1500/1500 [==============================] - 8s 6ms/step - loss: 0.0055 - accuracy: 0.9986 - val_loss: 0.0832 - val_accuracy: 0.9893
# Epoch 24/100
# 1500/1500 [==============================] - 7s 5ms/step - loss: 0.0056 - accuracy: 0.9985 - val_loss: 0.0666 - val_accuracy: 0.9918
# Epoch 25/100
# 1500/1500 [==============================] - 8s 6ms/step - loss: 0.0039 - accuracy: 0.9991 - val_loss: 0.0727 - val_accuracy: 0.9907
# Epoch 26/100
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.0048 - accuracy: 0.9988 - val_loss: 0.0698 - val_accuracy: 0.9912
# Epoch 27/100
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.0035 - accuracy: 0.9992 - val_loss: 0.0819 - val_accuracy: 0.9913
# Epoch 28/100
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.0039 - accuracy: 0.9991 - val_loss: 0.0738 - val_accuracy: 0.9906
# Epoch 29/100
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.0035 - accuracy: 0.9992 - val_loss: 0.1051 - val_accuracy: 0.9916
# Epoch 30/100
# 1500/1500 [==============================] - 7s 5ms/step - loss: 0.0064 - accuracy: 0.9988 - val_loss: 0.1059 - val_accuracy: 0.9902
# Epoch 31/100
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.0045 - accuracy: 0.9992 - val_loss: 0.0685 - val_accuracy: 0.9923
# Epoch 32/100
# 1500/1500 [==============================] - 7s 5ms/step - loss: 0.0033 - accuracy: 0.9992 - val_loss: 0.0842 - val_accuracy: 0.9899
# Epoch 33/100
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.0031 - accuracy: 0.9993 - val_loss: 0.1177 - val_accuracy: 0.9914
# Epoch 34/100
# 1500/1500 [==============================] - 8s 6ms/step - loss: 0.0036 - accuracy: 0.9991 - val_loss: 0.1125 - val_accuracy: 0.9887
# Epoch 35/100
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.0058 - accuracy: 0.9990 - val_loss: 0.0996 - val_accuracy: 0.9909
# Epoch 36/100
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.0032 - accuracy: 0.9991 - val_loss: 0.1464 - val_accuracy: 0.9891
# Epoch 37/100
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.0052 - accuracy: 0.9988 - val_loss: 0.1329 - val_accuracy: 0.9888
# Epoch 38/100
# 1500/1500 [==============================] - 7s 5ms/step - loss: 0.0033 - accuracy: 0.9994 - val_loss: 0.1167 - val_accuracy: 0.9915
# Epoch 39/100
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.0072 - accuracy: 0.9988 - val_loss: 0.1318 - val_accuracy: 0.9920
# Epoch 40/100
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.0025 - accuracy: 0.9995 - val_loss: 0.1058 - val_accuracy: 0.9921
# Epoch 41/100
# 1500/1500 [==============================] - 7s 5ms/step - loss: 0.0027 - accuracy: 0.9995 - val_loss: 0.1593 - val_accuracy: 0.9920
# Epoch 42/100
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.0092 - accuracy: 0.9987 - val_loss: 0.1556 - val_accuracy: 0.9904
# Epoch 43/100
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.0030 - accuracy: 0.9995 - val_loss: 0.1101 - val_accuracy: 0.9937
# Epoch 44/100
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.0043 - accuracy: 0.9992 - val_loss: 0.1170 - val_accuracy: 0.9918
# Epoch 45/100
# 1500/1500 [==============================] - 8s 6ms/step - loss: 0.0039 - accuracy: 0.9993 - val_loss: 0.1047 - val_accuracy: 0.9920
# Epoch 46/100
# 1500/1500 [==============================] - 7s 5ms/step - loss: 0.0037 - accuracy: 0.9994 - val_loss: 0.1502 - val_accuracy: 0.9918
# Epoch 47/100
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.0049 - accuracy: 0.9992 - val_loss: 0.1177 - val_accuracy: 0.9931
# Epoch 48/100
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.0064 - accuracy: 0.9991 - val_loss: 0.1218 - val_accuracy: 0.9918
# Epoch 49/100
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.0045 - accuracy: 0.9991 - val_loss: 0.1084 - val_accuracy: 0.9920
# Epoch 50/100
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.0020 - accuracy: 0.9995 - val_loss: 0.1297 - val_accuracy: 0.9917
# Epoch 51/100
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.0042 - accuracy: 0.9995 - val_loss: 0.1495 - val_accuracy: 0.9888
# Epoch 52/100
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.0063 - accuracy: 0.9992 - val_loss: 0.1098 - val_accuracy: 0.9924
# Epoch 53/100
# 1500/1500 [==============================] - 8s 6ms/step - loss: 0.0045 - accuracy: 0.9992 - val_loss: 0.1336 - val_accuracy: 0.9919
# Epoch 54/100
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.0036 - accuracy: 0.9995 - val_loss: 0.1332 - val_accuracy: 0.9927
# Epoch 55/100
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.0042 - accuracy: 0.9994 - val_loss: 0.1131 - val_accuracy: 0.9922
# Epoch 56/100
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.0044 - accuracy: 0.9994 - val_loss: 0.1487 - val_accuracy: 0.9912
# Epoch 57/100
# 1500/1500 [==============================] - 7s 5ms/step - loss: 0.0052 - accuracy: 0.9993 - val_loss: 0.1112 - val_accuracy: 0.9921
# Epoch 58/100
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.0027 - accuracy: 0.9995 - val_loss: 0.1458 - val_accuracy: 0.9918
# Epoch 59/100
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.0061 - accuracy: 0.9994 - val_loss: 0.2120 - val_accuracy: 0.9905
# Epoch 60/100
# 1500/1500 [==============================] - 7s 5ms/step - loss: 0.0040 - accuracy: 0.9995 - val_loss: 0.1541 - val_accuracy: 0.9927
# Epoch 61/100
# 1500/1500 [==============================] - 8s 6ms/step - loss: 0.0068 - accuracy: 0.9991 - val_loss: 0.2131 - val_accuracy: 0.9914
# Epoch 62/100
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.0037 - accuracy: 0.9996 - val_loss: 0.2230 - val_accuracy: 0.9911
# Epoch 63/100
# 1500/1500 [==============================] - 7s 5ms/step - loss: 0.0051 - accuracy: 0.9992 - val_loss: 0.2338 - val_accuracy: 0.9919
# Epoch 64/100
# 1500/1500 [==============================] - 9s 6ms/step - loss: 0.0056 - accuracy: 0.9996 - val_loss: 0.1968 - val_accuracy: 0.9925
# Epoch 65/100
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.0039 - accuracy: 0.9995 - val_loss: 0.2514 - val_accuracy: 0.9918
# Epoch 66/100
# 1500/1500 [==============================] - 7s 5ms/step - loss: 0.0071 - accuracy: 0.9994 - val_loss: 0.2671 - val_accuracy: 0.9921
# Epoch 67/100
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.0039 - accuracy: 0.9996 - val_loss: 0.3815 - val_accuracy: 0.9902
# Epoch 68/100
# 1500/1500 [==============================] - 7s 5ms/step - loss: 0.0090 - accuracy: 0.9993 - val_loss: 0.2151 - val_accuracy: 0.9921
# Epoch 69/100
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.0079 - accuracy: 0.9995 - val_loss: 0.3047 - val_accuracy: 0.9901
# Epoch 70/100
# 1500/1500 [==============================] - 9s 6ms/step - loss: 0.0050 - accuracy: 0.9994 - val_loss: 0.3572 - val_accuracy: 0.9917
# Epoch 71/100
# 1500/1500 [==============================] - 7s 5ms/step - loss: 0.0029 - accuracy: 0.9997 - val_loss: 0.2552 - val_accuracy: 0.9919
# Epoch 72/100
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.0090 - accuracy: 0.9992 - val_loss: 0.2751 - val_accuracy: 0.9912
# Epoch 73/100
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.0058 - accuracy: 0.9994 - val_loss: 0.2828 - val_accuracy: 0.9916
# Epoch 74/100
# 1500/1500 [==============================] - 7s 5ms/step - loss: 0.0071 - accuracy: 0.9993 - val_loss: 0.2828 - val_accuracy: 0.9925
# Epoch 75/100
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.0060 - accuracy: 0.9996 - val_loss: 0.3785 - val_accuracy: 0.9907
# Epoch 76/100
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.0042 - accuracy: 0.9997 - val_loss: 0.2738 - val_accuracy: 0.9912
# Epoch 77/100
# 1500/1500 [==============================] - 7s 5ms/step - loss: 0.0053 - accuracy: 0.9995 - val_loss: 0.2008 - val_accuracy: 0.9903
# Epoch 78/100
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.0059 - accuracy: 0.9995 - val_loss: 0.2797 - val_accuracy: 0.9912
# Epoch 79/100
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.0062 - accuracy: 0.9995 - val_loss: 0.2734 - val_accuracy: 0.9917
# Epoch 80/100
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.0068 - accuracy: 0.9994 - val_loss: 0.2601 - val_accuracy: 0.9919
# Epoch 81/100
# 1500/1500 [==============================] - 8s 6ms/step - loss: 0.0099 - accuracy: 0.9994 - val_loss: 0.2576 - val_accuracy: 0.9923
# Epoch 82/100
# 1500/1500 [==============================] - 7s 5ms/step - loss: 0.0010 - accuracy: 0.9998 - val_loss: 0.2782 - val_accuracy: 0.9927
# Epoch 83/100
# 1500/1500 [==============================] - 8s 6ms/step - loss: 0.0085 - accuracy: 0.9994 - val_loss: 0.3642 - val_accuracy: 0.9909
# Epoch 84/100
# 1500/1500 [==============================] - 8s 6ms/step - loss: 0.0061 - accuracy: 0.9995 - val_loss: 0.2925 - val_accuracy: 0.9923
# Epoch 85/100
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.0079 - accuracy: 0.9994 - val_loss: 0.3044 - val_accuracy: 0.9905
# Epoch 86/100
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.0047 - accuracy: 0.9996 - val_loss: 0.3009 - val_accuracy: 0.9915
# Epoch 87/100
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.0033 - accuracy: 0.9997 - val_loss: 0.3421 - val_accuracy: 0.9916
# Epoch 88/100
# 1500/1500 [==============================] - 7s 5ms/step - loss: 0.0033 - accuracy: 0.9997 - val_loss: 0.3301 - val_accuracy: 0.9912
# Epoch 89/100
# 1500/1500 [==============================] - 9s 6ms/step - loss: 0.0107 - accuracy: 0.9991 - val_loss: 0.3072 - val_accuracy: 0.9913
# Epoch 90/100
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.0042 - accuracy: 0.9995 - val_loss: 0.3743 - val_accuracy: 0.9923
# Epoch 91/100
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.0068 - accuracy: 0.9995 - val_loss: 0.3018 - val_accuracy: 0.9923
# Epoch 92/100
# 1500/1500 [==============================] - 8s 6ms/step - loss: 0.0064 - accuracy: 0.9995 - val_loss: 0.2524 - val_accuracy: 0.9922
# Epoch 93/100
# 1500/1500 [==============================] - 8s 6ms/step - loss: 0.0038 - accuracy: 0.9996 - val_loss: 0.3097 - val_accuracy: 0.9908
# Epoch 94/100
# 1500/1500 [==============================] - 7s 5ms/step - loss: 0.0071 - accuracy: 0.9994 - val_loss: 0.2617 - val_accuracy: 0.9921
# Epoch 95/100
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.0064 - accuracy: 0.9995 - val_loss: 0.2725 - val_accuracy: 0.9916
# Epoch 96/100
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.0039 - accuracy: 0.9996 - val_loss: 0.3591 - val_accuracy: 0.9906
# Epoch 97/100
# 1500/1500 [==============================] - 7s 5ms/step - loss: 0.0091 - accuracy: 0.9993 - val_loss: 0.2297 - val_accuracy: 0.9918
# Epoch 98/100
# 1500/1500 [==============================] - 8s 6ms/step - loss: 0.0054 - accuracy: 0.9997 - val_loss: 0.2998 - val_accuracy: 0.9908
# Epoch 99/100
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.0072 - accuracy: 0.9994 - val_loss: 0.2189 - val_accuracy: 0.9916
# Epoch 100/100
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.0040 - accuracy: 0.9996 - val_loss: 0.3524 - val_accuracy: 0.9919

# %% [markdown]
# 학습 시 매 에포크에 해당하는 훈련셋과 검증셋에 대한 손실값과 평가 메트릭 수치를 확인할 수 있습니다. 이를 시각화시키면 어느 에포크에서 오버피팅이 일어났는 지 한 눈에 확인할 수 있습니다.

# %%
fig, loss_ax = plt.subplots()

acc_ax = loss_ax.twinx()

loss_ax.plot(hist.history['loss'], 'y', label='train loss')
loss_ax.plot(hist.history['val_loss'], 'r', label='val loss')

acc_ax.plot(hist.history['accuracy'], 'b', label='train acc')
acc_ax.plot(hist.history['val_accuracy'], 'g', label='val acc')

loss_ax.set_xlabel('epoch')
loss_ax.set_ylabel('loss')
acc_ax.set_ylabel('accuray')

loss_ax.legend(loc='upper left')
acc_ax.legend(loc='lower left')

plt.show()

# %% [markdown]
# 파일로 저장된 모델을 로딩하여 시험셋으로 최종 평가를 수행합니다.

# %%
model = load_model("best_model.h5")

test_loss, test_acc = model.evaluate(x_test, y_test)

print("Test accuracy", test_acc)
print("Test loss", test_loss)
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0294 - accuracy: 0.9912
# Test accuracy 0.9911999702453613
# Test loss 0.029409313574433327
